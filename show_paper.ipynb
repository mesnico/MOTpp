# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import yaml
# %matplotlib inline

from pathlib import Path
from omegaconf import OmegaConf
from IPython.display import HTML

# %%
def collect_one(run, csv_folder):
    with open(run / 'config.json', 'r') as f:
        cfg = json.load(f)
    
    tpt = "-tpt{}".format(cfg['model']['text_encoder']['num_prompt_tokens']) if 'num_prompt_tokens' in cfg['model']['text_encoder'] else ''
    text_model = cfg['model']['text_encoder']['_target_'].replace('src.model.', '')
    text_model = f"{text_model}{tpt}"

    model = cfg['model']['_target_'].replace('src.model.', '')
    if model.lower() == 'rehamot':
        sim = cfg['model']['sim']['_target_'].replace('src.model.', '')
        lr = cfg['model']['lr']
        model = f"{model}-{sim}-lr{lr}"
    motion_model = cfg['model']['motion_encoder']['_target_'].replace('src.model.', '')

    no_bkb = '_nobkb' if 'bkb_feats' in cfg['model']['contrastive_loss'] and not cfg['model']['contrastive_loss']['bkb_feats'] else ''
    contrastive_loss = f"_{cfg['model']['contrastive_loss']['infonce_loss_fn']['_target_'].replace('src.model.', '')}" if 'infonce_loss_fn' in cfg['model']['contrastive_loss'] and cfg['model']['contrastive_loss']['infonce_loss_fn'] is not None else ''
    lambda_start_epoch = f"_{cfg['model']['contrastive_loss']['lambda_start_epoch']}" if 'lambda_start_epoch' in cfg['model']['contrastive_loss'] and cfg['model']['contrastive_loss']['lambda_start_epoch'] is not None else ''
    lambda_end_epoch = f"_{cfg['model']['contrastive_loss']['lambda_end_epoch']}" if 'lambda_end_epoch' in cfg['model']['contrastive_loss'] and cfg['model']['contrastive_loss']['lambda_end_epoch'] is not None else ''
    klloss = f"_{cfg['model']['contrastive_loss']['cross_consistent_type']}" if 'cross_consistent_type' in cfg['model']['contrastive_loss'] and cfg['model']['contrastive_loss']['cross_consistent_type'] is not None else ''
    pseudolab = f"_pseudolab{cfg['model']['contrastive_loss']['use_length_as_pseudo_motion_label']}" if 'use_length_as_pseudo_motion_label' in cfg['model']['contrastive_loss'] and cfg['model']['contrastive_loss']['use_length_as_pseudo_motion_label'] is not None else ''
    no_teacher_m2m = '_no-teacher-m2m' if 'text_teacher_affects_m2m' in cfg['model']['contrastive_loss'] and not cfg['model']['contrastive_loss']['text_teacher_affects_m2m'] else ''
    no_teacher_t2t = '_no-teacher-t2t' if 'text_teacher_affects_t2t' in cfg['model']['contrastive_loss'] and not cfg['model']['contrastive_loss']['text_teacher_affects_t2t'] else ''
    loss = cfg['model']['contrastive_loss']['_target_'].replace('src.model.', '') + no_bkb + contrastive_loss + klloss + lambda_start_epoch + lambda_end_epoch + pseudolab + no_teacher_m2m + no_teacher_t2t
    if 'threshold_selfsim' in cfg['model']['contrastive_loss'] and cfg['model']['contrastive_loss']['threshold_selfsim'] is None:
        loss = loss.replace('_with_filtering', '')

    dataset_test = csv_folder.split('_latest')[0]
    dataset_train = cfg['data']['test']['path'].split('/')[-1]
    dataset = dataset_train + '->' + dataset_test # dataset_test
    
    common_space_dim = cfg['common_space_dim']
    data_rep = cfg['data_rep']

    if 'ACTOR' in motion_model:
        motion_debug = '-debug-joints' if 'debug_encode_decode_joints' in cfg['model']['motion_encoder'] and cfg['model']['motion_encoder']['debug_encode_decode_joints'] else ''
        with_feet = '-withfeet' if 'with_feet' in cfg['model']['motion_encoder'] and cfg['model']['motion_encoder']['with_feet'] else ''
        motion_model = motion_model + motion_debug + with_feet

    if 'MoViT' in motion_model:
        time_mask = 'use_time_padding_mask' in cfg['model']['motion_encoder'] and cfg['model']['motion_encoder']['use_time_padding_mask']
        graph_based = 'use_skeleton_connection_mask' in cfg['model']['motion_encoder'] and cfg['model']['motion_encoder']['use_skeleton_connection_mask']
        time_mask = '-timemask' if time_mask else ''
        graph_based = '-graph' if graph_based else ''
        attention_type = '-' + cfg['model']['motion_encoder']['attention_type']
        uniform = '-uniform' if 'uniform_sample' in cfg['model']['motion_encoder'] and cfg['model']['motion_encoder']['uniform_sample'] else ''
        num_frames = '-{num_frames}'.format(num_frames=cfg['model']['motion_encoder']['num_frames'])
        ff_dim = '-ff{ff_dim}'.format(ff_dim=cfg['model']['motion_encoder']['ff_dims']) if 'ff_dims' in cfg['model']['motion_encoder'] else ''
        num_layers = f"-{cfg['model']['motion_encoder']['num_transformer_layers']}layers" if 'num_transformer_layers' in cfg['model']['motion_encoder'] else ''
        motion_model = motion_model + '-' + cfg['model']['motion_encoder']['body_repres'] + time_mask + graph_based + uniform + attention_type + num_frames + ff_dim + num_layers
    
    data = []
    for yamlf in (run / csv_folder).rglob('*.yaml'):
        with open(yamlf, 'r') as f:
            m = yaml.load(f, Loader=yaml.FullLoader)
        fname = yamlf.stem
        split = fname.rsplit('_', 1)
        if len(split) == 2:
            protocol_name, threshold = split
            threshold = threshold.split('-')[1]
            data.append({'protocol': protocol_name, 'len_thresh': threshold, **m})
        elif len(split) == 1:
            protocol_name = split[0]
            data.append({'protocol': protocol_name, **m})

    data = pd.DataFrame(data)
    if data.empty:
        print(f'Pred folder is empty: {csv_folder}')
    
    data['text_model'] = text_model
    data['motion_model'] = motion_model
    data['model'] = model
    data['loss'] = loss
    data['dataset'] = dataset
    data['common_space_dim'] = common_space_dim
    data['data_rep'] = data_rep
    data['run'] = cfg['rep']
    
    return data

def collect_all(root, csv_folder):
    root = Path(root)
    metrics = [collect_one(csvf.parents[0], csvf.name) for csvf in list(root.rglob(csv_folder))]
    metrics = pd.concat(metrics, ignore_index=True)
    return metrics

default_fields_dict = {
    'R1': lambda x: u"{:.2f}".format(x),
    'R5': lambda x: u"{:.2f}".format(x),
    'R10': lambda x: u"{:.2f}".format(x),
    'meanr': lambda x: u"{:.1f}".format(x),
    'medr': lambda x: int(x),
    'spice': lambda x: u"{:.3f}".format(x),
    'spacy': lambda x: u"{:.3f}".format(x),
}

# %%
# Compute metrics for each detected run

def summarize_metrics(
        metrics, 
        protocol=None, 
        dataset=None, 
        text_model=None, 
        motion_model=None, 
        loss=None, 
        common_space_dim=[256], 
        data_rep=['cont_6d_plus_rifke'], 
        len_thresh=None, 
        melt=True, 
        run=None,
        decimals=2):

    id_vars = ['dataset', 'protocol', 'model', 'text_model', 'motion_model', 'loss', 'common_space_dim', 'data_rep']
    # if len_thresh column is present, add "len_thresh" to id_vars
    if 'len_thresh' in metrics.columns:
        id_vars.append('len_thresh')

    if run is None:
        metrics = metrics.groupby(id_vars).mean().reset_index()
    else:
        # take the first run (rows with run = 0)
        metrics = metrics[metrics['run'] == run]
    
    metrics.drop(columns="run", inplace=True)

    # create an "average" protocol which is obtained by averaging every metric across all protocols, for every id_vars
    id_vars_without_protocol = list(id_vars)
    id_vars_without_protocol.remove('protocol')
    metrics_avg = metrics.drop(columns='protocol').groupby(id_vars_without_protocol).mean().reset_index()
    metrics_avg['protocol'] = 'average'
    metrics = pd.concat([metrics, metrics_avg], ignore_index=True)

    if protocol is not None:
        metrics = metrics[metrics['protocol'].isin(protocol)]
        if len(protocol) == 1:
            metrics.drop(columns="protocol", inplace=True)
            id_vars.remove('protocol')
    if common_space_dim is not None:
        metrics = metrics[metrics['common_space_dim'].isin(common_space_dim)]
        if len(common_space_dim) == 1:
            metrics.drop(columns="common_space_dim", inplace=True)
            id_vars.remove('common_space_dim')
    if data_rep is not None:
        metrics = metrics[metrics['data_rep'].isin(data_rep)]
        if len(data_rep) == 1:
            metrics.drop(columns="data_rep", inplace=True)
            id_vars.remove('data_rep')
    if text_model is not None:
        metrics = metrics[metrics['text_model'].isin(text_model)]
        if len(text_model) == 1:
            metrics.drop(columns="text_model", inplace=True)
            id_vars.remove('text_model')
    if motion_model is not None:
        metrics = metrics[metrics['motion_model'].isin(motion_model)]
        if len(motion_model) == 1:
            metrics.drop(columns="motion_model", inplace=True)
            id_vars.remove('motion_model')
    if loss is not None:
        metrics = metrics[metrics['loss'].isin(loss)]
        if len(loss) == 1:
            metrics.drop(columns="loss", inplace=True)
            id_vars.remove('loss')
    if len_thresh is not None:
        metrics = metrics[metrics['len_thresh'].isin(len_thresh)]
        if len(len_thresh) == 1:
            metrics.drop(columns="len_thresh", inplace=True)
            id_vars.remove('len_thresh')
    if dataset is not None:
        metrics = metrics[(metrics['dataset'] == dataset)]
        metrics.drop(columns="dataset", inplace=True)
        id_vars.remove('dataset')

    if melt:
        metrics = metrics.melt(id_vars=id_vars, var_name="metric")
        metrics = metrics.pivot(index=id_vars, columns="metric", values="value")

    # round to 2 decimal places
    metrics = metrics.round(decimals)

    return metrics

# %%
# rename content of the table
def rename_fn(v):
    mapping = {'motions.MoViT_v2-body-parts-timemask-uniform-fact_encoder-200-ff1024-2layers': 'MoViT++',
               'motions.MoViT-body-parts-timemask-uniform-divided_space_time-200-3layers': 'MoViT',
               'losses.InfoNCECrossConsistent_kldiv_0_1': 'CCL self',
               'losses.InfoNCECrossConsistent_kldiv_80_140': 'CCL 80-140',
               'losses.InfoNCECrossConsistent_kldiv_40_100': 'CCL 40-100',
               'losses.InfoNCECrossConsistent_kldiv_140_200': 'CCL 140-200',
               'losses.InfoNCECrossConsistent_kldiv_500_600': 'CCL supervised',
               'losses.InfoNCECrossConsistent_kldiv_80_140_no-teacher-m2m': 'CCL 80-140 no-teacher-m2m',
               'losses.InfoNCECrossConsistent_kldiv_40_100_no-teacher-m2m': 'CCL 40-100 no-teacher-m2m',
               'losses.InfoNCECrossConsistent_kldiv_80_140_no-teacher-t2t': 'CCL 80-140 no-teacher-t2t',
               'losses.InfoNCECrossConsistent_kldiv_40_100_no-teacher-t2t': 'CCL 40-100 no-teacher-t2t',
               'losses.InfoNCE': 'InfoNCE',
               'losses.InfoNCE_with_filtering': 'InfoNCE+F',
               'ACTORStyleEncoder': 'TMR',
               'texts.CLIP': 'CLIP',
               }
    if v in mapping:
        return mapping[v]
    return v

def paper_formatting(metrics, remapping, order=None, protocols_order=['guo', 'normal', 'nsim', 'threshold_0.95', 'average']):
    index_cols = ['protocol', 'dataset', 'model', 'text_model', 'motion_model', 'loss']
    # metrics = metrics[metrics['loss'].isin(['losses.InfoNCECrossConsistent_kldiv_80_140', 'losses.InfoNCE_with_filtering', 'losses.InfoNCE'])]
    # rename values in the table
    metrics = metrics.applymap(rename_fn)
    # create multi-index where protocol is repeated
    metrics = metrics.set_index(index_cols)
    # metrics['model'] = metrics['motion_model'] + ' ' + metrics['text_model'] + ' ' + metrics['loss']
    metrics['Rsum'] = metrics['t2m/R01'] + metrics['t2m/R02'] + metrics['t2m/R03'] + metrics['t2m/R05'] + metrics['t2m/R10'] + \
                      metrics['m2t/R01'] + metrics['m2t/R02'] + metrics['m2t/R03'] + metrics['m2t/R05'] + metrics['m2t/R10']
    # metrics.drop(columns=['motion_model', 'text_model', 'loss'], inplace=True)
    # delete t2m/len and m2t/len columns
    metrics.drop(columns=['t2m/len', 'm2t/len'], inplace=True)
    # create multi-column where the top level is the columns beginning with "t2m" and "m2t"
    metrics.columns = pd.MultiIndex.from_tuples([(c.split('/')[0], c.split('/')[1]) if 'Rsum' not in c else ('Rsum', '') for c in metrics.columns])
    # sort columns by first level
    metrics = metrics.sort_index(axis=1)
    # rename the first level of the columns: from "t2m" to "Text-to-Motion" and from "m2t" to "Motion-to-Text"
    #metrics.columns = metrics.columns.set_levels(['Motion-to-Text', 'Text-to-Motion'], level=0)

    # reorder columns and rows
    #metrics = metrics.reindex(columns=['R01', 'R02', 'R03', 'R05', 'R10', 'MedR'], level=1)
    metrics = metrics.reindex(["m2t", "t2m", "Rsum"], axis=1, level=0)

    # select only the rows that are in the selections
    # idx = pd.IndexSlice
    # selections = list(remapping.keys())
    # metrics = metrics.loc[idx[:, [x[0] for x in selections], [x[1] for x in selections], [x[2] for x in selections], [x[3] for x in selections]], :]
    # Step 2: Extract levels 1 to 3 and apply the mapping
    mapped_part = metrics.index.to_frame(index=False).loc[:, ['dataset', 'model', 'text_model', 'motion_model', 'loss']].apply(tuple, axis=1).map(remapping)

    # Step 3: Combine level 0 with the mapped part
    new_index = pd.MultiIndex.from_arrays([metrics.index.get_level_values(0), mapped_part], names=['protocol', 'method'])

    # Step 4: Set the new index to the DataFrame
    metrics.index = new_index

    # delete rows where method part of the index is NaN
    c = metrics.index.names
    metrics = metrics.reset_index().dropna().set_index(c)

    # order the rows by protocol
    metrics = metrics.reindex(protocols_order, level=0)

    if order is not None:
        metrics = metrics.reindex(order, level=1)

    return metrics

def render_to_latex(metrics, rename_func=default_fields_dict, **latex_kwargs):
    m = metrics.copy()
     # make bold the best values

    # Custom function to highlight the maximum value in each group
    def highlight_best(data):
        attr = 'font-weight: bold'
        result = pd.DataFrame('', index=data.index, columns=data.columns)
        for col in data.columns:
            if 'MedR' in col:
                best_idx = data.groupby(level=0)[[col]].idxmin()
            else:
                best_idx = data.groupby(level=0)[[col]].idxmax()
            for idx in best_idx.values:
                result.loc[idx, col] = attr
        return result

    styled_df = m.style.apply(highlight_best, axis=None)
    ltex = styled_df.format(precision=2).to_latex(
        **latex_kwargs
    )
    return ltex

# %% [markdown]
# # Train: HumanML3D. Test: KIT

# %%
# collect all data on humanml+kit (tested on kit)
ROOT = "runs"

metrics = collect_all(ROOT, '*latest_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
metrics = summarize_metrics(
    metrics, 
    # loss=['losses.InfoNCE_with_filtering', 
    #       'losses.InfoNCE_with_filtering',
    #       'losses.InfoNCECrossConsistent_losses.InfoNCE_with_filtering_kldiv_500_600', 
    #       'losses.InfoNCECrossConsistent_losses.InfoNCE_with_filtering_kldiv_80_140'], #InfoNCELoss', 'InfoNCECrossConsistent_symm', 'InfoNCECrossConsistent_symm_nobkb'],
    data_rep=['cont_6d_plus_rifke_vels'], # 'cont_6d_plus_rifke',
    len_thresh=[
        # '1.5',
        # '2.0',
        'None'
    ],
    melt=False,
    )

selection = {
    ('humanml3d->kitml', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D)',
    ('humanml3d->kitml', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR',
    ('humanml3d->kitml', 'T2M', 'CLIP', 'MoViT', 'InfoNCE'): 'MoT',
    ('humanml3d->kitml', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100'): 'MoT++',
    ('humanml3d->humanml3d', 'Rehamot-CosineSim-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot Cosine',
    ('humanml3d->humanml3d', 'Rehamot-CrossPerceptualSalienceMapping-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot CPS',
}

# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ self', 'MoT++ 40-100', 'MoT++ 80-140', 'MoT++ 140-200', 'MoT++ supervised']
order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++', 'TMR (only HML3D) wo-KIT', 'TMR wo-KIT', 'MoT wo-KIT', 'MoT++ wo-KIT', 'Rehamot Cosine', 'Rehamot CPS']
metrics = paper_formatting(metrics, selection, order=order)

metrics

# latex = render_to_latex(
#     metrics, 
#     caption="Train: HumanML, Test: KIT",
#     clines="skip-last;data",
#     hrules=True,
#     column_format="llccccccccccccc",
#     convert_css=True
# )

# print(latex)

# %% [markdown]
# # Train: KIT+Humanml. Test: HumanML3D

# %%
# collect all data on humanml+kit (tested on kit)
pd.set_option('display.max_rows', None)
ROOT = "runs"

metrics = collect_all(ROOT, '*latest_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
# metrics = collect_all(ROOT, '*best-rsum_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
metrics = summarize_metrics(
    metrics, 
    data_rep=['cont_6d_plus_rifke_vels'], # 'cont_6d_plus_rifke',
    len_thresh=[
        # '1.5',
        # '2.0',
        'None'
    ],
    melt=False
    )

selection = {
    ('humanml3d->humanml3d', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D)',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'CLIP', 'MoViT', 'InfoNCE'): 'MoT',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'MoViT', 'CCL 40-100'): 'MoT++ with MOTv1 encoder',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100'): 'MoT++',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 80-140 no-teacher-m2m'): 'MoT++ 80-140 ntm', 
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100 no-teacher-m2m'): 'MoT++ 40-100 ntm',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 80-140 no-teacher-t2t'): 'MoT++ 80-140 ntt', 
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100 no-teacher-t2t'): 'MoT++ 40-100 ntt',
    ('humanml3d_plus_kitml->humanml3d', 'Rehamot-CosineSim-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot Cosine',
    ('humanml3d_plus_kitml->humanml3d', 'Rehamot-CrossPerceptualSalienceMapping-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot CPS',
}

# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ self', 'MoT++ 40-100', 'MoT++ 80-140', 'MoT++ 140-200', 'MoT++ supervised']
# order = ['TMR (only HML3D)', 'TMR (only HML3D wo-KIT)', 'TMR', 'MoT', 'MoT++', 'MoT++ with MOTv1 encoder', 'MoT++ wo-KIT', 'MoT++ 80-140 ntm', 'MoT++ 40-100 ntm', 'MoT++ 80-140 ntt', 'MoT++ 40-100 ntt', 'Rehamot Cosine', 'Rehamot CPS']
order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++', 'MoT++ with MOTv1 encoder', 'Rehamot Cosine', 'Rehamot CPS', 'TMR (only HML3D wo-KIT)', 'TMR wo-KIT', 'MoT wo-KIT', 'MoT++ wo-KIT', 'Rehamot Cosine wo-KIT', 'Rehamot CPS wo-KIT']
metrics = paper_formatting(metrics, selection, order=order)

metrics

# latex = render_to_latex(
#     metrics, 
#     caption="Train: KIT+HumanML, Test: HumanML",
#     clines="skip-last;data",
#     hrules=True,
#     column_format="llccccccccccccc",
#     convert_css=True
# )

# print(latex)

# %% [markdown]
# # Train: KIT+Humanml. Test: KITML

# %%
# collect all data on humanml+kit (tested on kit)
ROOT = "runs"

metrics = collect_all(ROOT, '*latest_contrastive-metrics')
# metrics = collect_all(ROOT, '*best-rsum_contrastive-metrics')
metrics = summarize_metrics(
    metrics, 
    data_rep=['cont_6d_plus_rifke_vels'], # 'cont_6d_plus_rifke',
    len_thresh=[
        # '1.5',
        # '2.0',
        'None'
    ],
    melt=False,
    )

selection = {
    ('humanml3d->kitml', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D)',
    ('humanml3d->kitml', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D wo-KIT)',
    ('humanml3d_plus_kitml->kitml', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR',
    ('humanml3d_plus_kitml->kitml', 'T2M', 'CLIP', 'MoViT', 'InfoNCE'): 'MoT',
    ('humanml3d_plus_kitml->kitml', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100'): 'MoT++',
    ('humanml3d_plus_kitml->kitml', 'T2M', 'TMR', 'MoViT', 'CCL 40-100'): 'MoT++ with MOTv1 encoder',
    ('humanml3d_plus_kitml->kitml', 'T2M', 'TMR', 'MoViT++', 'CCL 80-140 no-teacher-m2m'): 'MoT++ 80-140 ntm',
    ('humanml3d_plus_kitml->kitml', 'T2M', 'TMR', 'TMR', 'CCL 80-140 no-teacher-m2m'): 'TMR 80-140 ntm', 
    ('humanml3d_plus_kitml->kitml', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100 no-teacher-m2m'): 'MoT++ 40-100 ntm',
    ('humanml3d_plus_kitml->kitml', 'T2M', 'TMR', 'TMR', 'CCL 40-100 no-teacher-m2m'): 'TMR 40-100 ntm',
    ('humanml3d_plus_kitml->kitml', 'Rehamot-CosineSim-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot Cosine',
    ('humanml3d_plus_kitml->kitml', 'Rehamot-CrossPerceptualSalienceMapping-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot CPS',
}

# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ self', 'MoT++ 40-100', 'MoT++ 80-140', 'MoT++ 140-200', 'MoT++ supervised']
# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++', 'MoT++ 80-140 ntm', 'MoT++ 40-100 ntm', 'TMR 80-140 ntm', 'TMR 40-100 ntm']
order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++', 'MoT++ with MOTv1 encoder', 'Rehamot Cosine', 'Rehamot CPS', 'TMR (only HML3D wo-KIT)', 'TMR wo-KIT', 'MoT wo-KIT', 'MoT++ wo-KIT', 'Rehamot Cosine wo-KIT', 'Rehamot CPS wo-KIT']

metrics = paper_formatting(metrics, selection, order)
metrics
# latex = render_to_latex(
#     metrics, 
#     caption="Train: KIT+HumanML, Test: KIT",
#     clines="skip-last;data",
#     hrules=True,
#     column_format="llccccccccccccc",
#     convert_css=True
# )

# print(latex)

# %% [markdown]
# # Ablations on MoT++ Encoder (Train on KIT+HML, Test on HML)

# %%
# collect all data on humanml+kit (tested on kit)
pd.set_option('display.max_rows', None)
ROOT = "runs"

metrics = collect_all(ROOT, '*latest_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
# metrics = collect_all(ROOT, '*best-rsum_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
metrics = summarize_metrics(
    metrics, 
    data_rep=['cont_6d_plus_rifke_vels'], # 'cont_6d_plus_rifke',
    len_thresh=[
        # '1.5',
        # '2.0',
        'None'
    ],
    melt=False
    )

selection = {
    ('humanml3d->humanml3d', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D)',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'CLIP', 'MoViT', 'InfoNCE'): 'MoT',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'MoViT', 'CCL 40-100'): 'MoT++ with MOTv1 encoder',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100'): 'MoT++',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'motions.MoViT_v2-body-parts-timemask-uniform-divided_space_time-200-ff1024-2layers', 'CCL 40-100'): 'MoT++ divided space time',
    ('humanml3d_plus_kitml->humanml3d', 'T2M', 'TMR', 'motions.MoViT_v2-body-parts-timemask-uniform-joint_space_time-200-ff1024-2layers', 'CCL 40-100'): 'MoT++ joint space time',
}

# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ self', 'MoT++ 40-100', 'MoT++ 80-140', 'MoT++ 140-200', 'MoT++ supervised']
# order = ['TMR (only HML3D)', 'TMR (only HML3D wo-KIT)', 'TMR', 'MoT', 'MoT++', 'MoT++ with MOTv1 encoder', 'MoT++ wo-KIT', 'MoT++ 80-140 ntm', 'MoT++ 40-100 ntm', 'MoT++ 80-140 ntt', 'MoT++ 40-100 ntt', 'Rehamot Cosine', 'Rehamot CPS']
order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ with MOTv1 encoder', 'MoT++ divided space time', 'MoT++ joint space time', 'MoT++']
metrics = paper_formatting(metrics, selection, order=order)

metrics

# latex = render_to_latex(
#     metrics, 
#     caption="Train: KIT+HumanML, Test: HumanML",
#     clines="skip-last;data",
#     hrules=True,
#     column_format="llccccccccccccc",
#     convert_css=True
# )

# print(latex)

# %% [markdown]
# # Train: Motion-X; Test: Humanml3D

# %%
# collect all data on humanml+kit (tested on kit)
pd.set_option('display.max_rows', None)
ROOT = "runs"

metrics = collect_all(ROOT, '*latest_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
# metrics = collect_all(ROOT, '*best-rsum_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
metrics = summarize_metrics(
    metrics, 
    data_rep=['cont_6d_plus_rifke_vels'], # 'cont_6d_plus_rifke',
    len_thresh=[
        # '1.5',
        # '2.0',
        'None'
    ],
    melt=False
    )

selection = {
    ('motionx->humanml3d', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D)',
    ('motionx->humanml3d', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR',
    ('motionx->humanml3d', 'T2M', 'CLIP', 'MoViT', 'InfoNCE'): 'MoT',
    ('motionx->humanml3d', 'T2M', 'TMR', 'MoViT', 'CCL 40-100'): 'MoT++ with MOTv1 encoder',
    #('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'CCL self'): 'MoT++ self',
    ('motionx->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100'): 'MoT++',
    #('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'CCL 80-140'): 'MoT++ 80-140',
    #('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'CCL 140-200'): 'MoT++',
    #('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'CCL supervised'): 'MoT++ supervised',
    ('motionx->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 80-140 no-teacher-m2m'): 'MoT++ 80-140 ntm', 
    ('motionx->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100 no-teacher-m2m'): 'MoT++ 40-100 ntm',
    ('motionx->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 80-140 no-teacher-t2t'): 'MoT++ 80-140 ntt', 
    ('motionx->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100 no-teacher-t2t'): 'MoT++ 40-100 ntt',
    ('motionx->humanml3d', 'Rehamot-CosineSim-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot Cosine',
    ('motionx->humanml3d', 'Rehamot-CrossPerceptualSalienceMapping-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot CPS',
    # ('humanml3d_plus_kitml->humanml3d', 'Rehamot-CosineSim-lr5e-05', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot Cosine Our Setting',
    # ('humanml3d_plus_kitml->humanml3d', 'Rehamot-CrossPerceptualSalienceMapping-lr5e-05', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot CPS Our Setting',
}

# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ self', 'MoT++ 40-100', 'MoT++ 80-140', 'MoT++ 140-200', 'MoT++ supervised']
# order = ['TMR (only HML3D)', 'TMR (only HML3D wo-KIT)', 'TMR', 'MoT', 'MoT++', 'MoT++ with MOTv1 encoder', 'MoT++ wo-KIT', 'MoT++ 80-140 ntm', 'MoT++ 40-100 ntm', 'MoT++ 80-140 ntt', 'MoT++ 40-100 ntt', 'Rehamot Cosine', 'Rehamot CPS']
order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++', 'MoT++ with MOTv1 encoder', 'Rehamot Cosine', 'Rehamot CPS', 'TMR (only HML3D wo-KIT)', 'TMR wo-KIT', 'MoT wo-KIT', 'MoT++ wo-KIT', 'Rehamot Cosine wo-KIT', 'Rehamot CPS wo-KIT']
metrics = paper_formatting(metrics, selection, order=order)

metrics

# latex = render_to_latex(
#     metrics, 
#     caption="Train: KIT+HumanML, Test: HumanML",
#     clines="skip-last;data",
#     hrules=True,
#     column_format="llccccccccccccc",
#     convert_css=True
# )

# print(latex)

# %% [markdown]
# # Train: Motion-X + Humanml3D; Test: Humanml3D

# %%
# collect all data on humanml+kit (tested on kit)
pd.set_option('display.max_rows', None)
ROOT = "runs"

metrics = collect_all(ROOT, '*latest_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
# metrics = collect_all(ROOT, '*best-rsum_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
metrics = summarize_metrics(
    metrics, 
    data_rep=['cont_6d_plus_rifke_vels'], # 'cont_6d_plus_rifke',
    len_thresh=[
        # '1.5',
        # '2.0',
        'None'
    ],
    melt=False
    )

selection = {
    ('motionx_plus_humanml3d->humanml3d', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D)',
    ('motionx_plus_humanml3d->humanml3d', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR',
    ('motionx_plus_humanml3d->humanml3d', 'T2M', 'CLIP', 'MoViT', 'InfoNCE'): 'MoT',
    ('motionx_plus_humanml3d->humanml3d', 'T2M', 'TMR', 'MoViT', 'CCL 40-100'): 'MoT++ with MOTv1 encoder',
    ('motionx_plus_humanml3d->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100'): 'MoT++',
    ('motionx_plus_humanml3d->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 80-140 no-teacher-m2m'): 'MoT++ 80-140 ntm', 
    ('motionx_plus_humanml3d->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100 no-teacher-m2m'): 'MoT++ 40-100 ntm',
    ('motionx_plus_humanml3d->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 80-140 no-teacher-t2t'): 'MoT++ 80-140 ntt', 
    ('motionx_plus_humanml3d->humanml3d', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100 no-teacher-t2t'): 'MoT++ 40-100 ntt',
    ('motionx_plus_humanml3d->humanml3d', 'Rehamot-CosineSim-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot Cosine',
    ('motionx_plus_humanml3d->humanml3d', 'Rehamot-CrossPerceptualSalienceMapping-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot CPS',}

# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ self', 'MoT++ 40-100', 'MoT++ 80-140', 'MoT++ 140-200', 'MoT++ supervised']
# order = ['TMR (only HML3D)', 'TMR (only HML3D wo-KIT)', 'TMR', 'MoT', 'MoT++', 'MoT++ with MOTv1 encoder', 'MoT++ wo-KIT', 'MoT++ 80-140 ntm', 'MoT++ 40-100 ntm', 'MoT++ 80-140 ntt', 'MoT++ 40-100 ntt', 'Rehamot Cosine', 'Rehamot CPS']
order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++', 'MoT++ with MOTv1 encoder', 'Rehamot Cosine', 'Rehamot CPS', 'TMR (only HML3D wo-KIT)', 'TMR wo-KIT', 'MoT wo-KIT', 'MoT++ wo-KIT', 'Rehamot Cosine wo-KIT', 'Rehamot CPS wo-KIT']
metrics = paper_formatting(metrics, selection, order=order)

metrics

# latex = render_to_latex(
#     metrics, 
#     caption="Train: KIT+HumanML, Test: HumanML",
#     clines="skip-last;data",
#     hrules=True,
#     column_format="llccccccccccccc",
#     convert_css=True
# )

# print(latex)

# %% [markdown]
# # Train: Motion-X + Humanml3D; Test: KITML

# %%
# collect all data on humanml+kit (tested on kit)
pd.set_option('display.max_rows', None)
ROOT = "runs"

metrics = collect_all(ROOT, '*latest_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
# metrics = collect_all(ROOT, '*best-rsum_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
metrics = summarize_metrics(
    metrics, 
    data_rep=['cont_6d_plus_rifke_vels'], # 'cont_6d_plus_rifke',
    len_thresh=[
        # '1.5',
        # '2.0',
        'None'
    ],
    melt=False
    )

selection = {
    ('motionx_plus_humanml3d->kitml', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D)',
    ('motionx_plus_humanml3d->kitml', 'T2M', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR',
    ('motionx_plus_humanml3d->kitml', 'T2M', 'CLIP', 'MoViT', 'InfoNCE'): 'MoT',
    ('motionx_plus_humanml3d->kitml', 'T2M', 'TMR', 'MoViT', 'CCL 40-100'): 'MoT++ with MOTv1 encoder',
    ('motionx_plus_humanml3d->kitml', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100'): 'MoT++',
    ('motionx_plus_humanml3d->kitml', 'T2M', 'TMR', 'MoViT++', 'CCL 80-140 no-teacher-m2m'): 'MoT++ 80-140 ntm', 
    ('motionx_plus_humanml3d->kitml', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100 no-teacher-m2m'): 'MoT++ 40-100 ntm',
    ('motionx_plus_humanml3d->kitml', 'T2M', 'TMR', 'MoViT++', 'CCL 80-140 no-teacher-t2t'): 'MoT++ 80-140 ntt', 
    ('motionx_plus_humanml3d->kitml', 'T2M', 'TMR', 'MoViT++', 'CCL 40-100 no-teacher-t2t'): 'MoT++ 40-100 ntt',
    ('motionx_plus_humanml3d->kitml', 'Rehamot-CosineSim-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot Cosine',
    ('motionx_plus_humanml3d->kitml', 'Rehamot-CrossPerceptualSalienceMapping-lr0.0002', 'texts.DistilbertLinearEncoder', 'motions.TransformerRehamot', 'losses.SoftContrastiveLoss'): 'Rehamot CPS',
}

# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ self', 'MoT++ 40-100', 'MoT++ 80-140', 'MoT++ 140-200', 'MoT++ supervised']
# order = ['TMR (only HML3D)', 'TMR (only HML3D wo-KIT)', 'TMR', 'MoT', 'MoT++', 'MoT++ with MOTv1 encoder', 'MoT++ wo-KIT', 'MoT++ 80-140 ntm', 'MoT++ 40-100 ntm', 'MoT++ 80-140 ntt', 'MoT++ 40-100 ntt', 'Rehamot Cosine', 'Rehamot CPS']
order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++', 'MoT++ with MOTv1 encoder', 'Rehamot Cosine', 'Rehamot CPS', 'TMR (only HML3D wo-KIT)', 'TMR wo-KIT', 'MoT wo-KIT', 'MoT++ wo-KIT', 'Rehamot Cosine wo-KIT', 'Rehamot CPS wo-KIT']
metrics = paper_formatting(metrics, selection, order=order)

metrics

# latex = render_to_latex(
#     metrics, 
#     caption="Train: KIT+HumanML, Test: HumanML",
#     clines="skip-last;data",
#     hrules=True,
#     column_format="llccccccccccccc",
#     convert_css=True
# )

# print(latex)

# %% [markdown]
# # Ablations on different CCL versions (different hyperparameters configs) - MoT++

# %%
# collect all data on humanml+kit (tested on kit)
ROOT = "runs"

metrics = collect_all(ROOT, '*latest_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
metrics = summarize_metrics(
    metrics, 
    data_rep=['cont_6d_plus_rifke_vels'], # 'cont_6d_plus_rifke',
    len_thresh=[
        # '1.5',
        # '2.0',
        'None'
    ],
    melt=False
    )

selection = {
    # ('humanml3d->humanml3d', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D)',
    # ('humanml3d_plus_kitml->humanml3d', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR',
    # ('humanml3d_plus_kitml->humanml3d', 'CLIP', 'MoViT', 'InfoNCE'): 'MoT',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'InfoNCE+F'): 'InfoNCE+F',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'CCL self'): 'CCL self',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'CCL 40-100'): 'CCL 40-100', 
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'CCL 80-140'): 'CCL 80-140',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'CCL 140-200'): 'CCL 140-200',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'CCL supervised'): 'CCL supervised',
}

# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ self', 'MoT++ 40-100', 'MoT++ 80-140', 'MoT++ 140-200', 'MoT++ supervised']
order = ['InfoNCE+F', 'CCL self', 'CCL 40-100', 'CCL 80-140', 'CCL 140-200', 'CCL supervised']
metrics = paper_formatting(metrics, selection, order=order)
metrics

# latex = render_to_latex(
#     metrics, 
#     caption="CCL ablations on MoT++",
#     clines="skip-last;data",
#     hrules=True,
#     column_format="llccccccccccccc",
#     convert_css=True
# )

# print(latex)

# %% [markdown]
# # Ablations on different CCL versions (different hyperparameters configs) - TMR

# %%
# collect all data on humanml+kit (tested on kit)
ROOT = "runs"

metrics = collect_all(ROOT, '*latest_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
metrics = summarize_metrics(
    metrics, 
    data_rep=['cont_6d_plus_rifke_vels'], # 'cont_6d_plus_rifke',
    len_thresh=[
        # '1.5',
        # '2.0',
        'None'
    ],
    melt=False
    )

selection = {
    # ('humanml3d->humanml3d', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D)',
    # ('humanml3d_plus_kitml->humanml3d', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR',
    # ('humanml3d_plus_kitml->humanml3d', 'CLIP', 'MoViT', 'InfoNCE'): 'MoT',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'TMR', 'InfoNCE+F'): 'InfoNCE+F',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'TMR', 'CCL self'): 'CCL self',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'TMR', 'CCL 40-100'): 'CCL 40-100', 
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'TMR', 'CCL 80-140'): 'CCL 80-140',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'TMR', 'CCL 140-200'): 'CCL 140-200',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'TMR', 'CCL supervised'): 'CCL supervised',
}

# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ self', 'MoT++ 40-100', 'MoT++ 80-140', 'MoT++ 140-200', 'MoT++ supervised']
order = ['InfoNCE+F', 'CCL self', 'CCL 40-100', 'CCL 80-140', 'CCL 140-200', 'CCL supervised']
metrics = paper_formatting(metrics, selection, order=order)
metrics

# latex = render_to_latex(
#     metrics, 
#     caption="CCL ablations on TMR",
#     clines="skip-last;data",
#     hrules=True,
#     column_format="llccccccccccccc",
#     convert_css=True
# )

# print(latex)

# %% [markdown]
# # Ablations: MoT++ (InfoNCE+F, HumanMl3D)-> MoT++ (InfoNCE+F, Humanml3D+KIT), MoT++ (CCL, Humanml3D) -> MoT++ (CCL, Humanml3D+KIT)

# %%
# collect all data on humanml+kit (tested on kit)
ROOT = "runs"

metrics = collect_all(ROOT, '*latest_contrastive-metrics')   # '*best-rsum_contrastive-metrics'
metrics = summarize_metrics(
    metrics, 
    data_rep=['cont_6d_plus_rifke_vels'], # 'cont_6d_plus_rifke',
    len_thresh=[
        # '1.5',
        # '2.0',
        'None'
    ],
    melt=False
    )

selection = {
    # ('humanml3d->humanml3d', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR (only HML3D)',
    # ('humanml3d_plus_kitml->humanml3d', 'TMR', 'TMR', 'InfoNCE+F'): 'TMR',
    # ('humanml3d_plus_kitml->humanml3d', 'CLIP', 'MoViT', 'InfoNCE'): 'MoT',
    ('humanml3d->humanml3d', 'TMR', 'MoViT++', 'InfoNCE+F'): 'MoT++ HML3D InfoNCE+F',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'InfoNCE+F'): 'MoT++ HML3D+KIT InfoNCE+F',
    ('humanml3d->humanml3d', 'TMR', 'MoViT++', 'CCL 40-100'): 'MoT++ HML3D CCL',
    ('humanml3d_plus_kitml->humanml3d', 'TMR', 'MoViT++', 'CCL 40-100'): 'MoT++ HML3D+KIT CCL',
}

# order = ['TMR (only HML3D)', 'TMR', 'MoT', 'MoT++ self', 'MoT++ 40-100', 'MoT++ 80-140', 'MoT++ 140-200', 'MoT++ supervised']
order = ['MoT++ HML3D InfoNCE+F', 'MoT++ HML3D+KIT InfoNCE+F', 'MoT++ HML3D CCL', 'MoT++ HML3D+KIT CCL']
metrics = paper_formatting(metrics, selection, order=order)
metrics

# latex = render_to_latex(
#     metrics, 
#     caption="MoT++ ablations on joint dataset learning active / not active and CCL loss active / not active",
#     clines="skip-last;data",
#     hrules=True,
#     column_format="llccccccccccccc",
#     convert_css=True
# )

# print(latex)
